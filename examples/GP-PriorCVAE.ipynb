# %% [markdown]
# # Squared exponential kernel Gaussian process - PriorCVAE

# %% [markdown]
# This is a demo notebook to showcase the usage of PriorCVAE model on a Gaussian process dataset which is generated using a SquaredExponential kernel.

# %%
import random as rnd

import numpy as np 
import matplotlib.pyplot as plt
import numpyro
from numpyro.infer import Predictive
from numpyro.diagnostics import hpdi
numpyro.set_host_device_count(4)
import jax
import optax
from jax import random
import jax.numpy as jnp
import flax.linen as nn

from priorCVAE.models import MLPEncoder, MLPDecoder, VAE
from priorCVAE.priors import GP, SquaredExponential
from priorCVAE.mcmc import run_mcmc_vae, vae_mcmc_inference_model
from priorCVAE.datasets import GPDataset
from priorCVAE.trainer import VAETrainer
from priorCVAE.losses import SquaredSumAndKL, MMDAndKL

import jax.config as config
config.update("jax_enable_x64", True)

# %% [markdown]
# ### Configuration

# %%
args = {
        "conditional": True,
        
        # architecture
        "input_dim" : 80,
        "hidden_dim": 60,
        "activation_fn": nn.leaky_relu,
        "latent_dim": 40,
        
        # VAE training    
        "batch_size": 500,
        "num_iterations": 4000,
        "learning_rate": 1e-3,
        "vae_var": 1.,
        "loss": "SquaredSumAndKL",  # [SquaredSumAndKL, MMDAndKL]

        # MCMC inference
        "true_ls": 0.2,
        "num_warmup": 1000,
        "num_mcmc_samples": 4000,
        "num_chains": 4,
        "thinning": 1,
       }

# %% [markdown]
# ### Generate data
#
# We generate the data using an SquaredExponential kernel with lengthscale that is uniformly sampled. We plot a sample from the GP and plot the trajectories and lengthscales.

# %%
kernel = SquaredExponential()

gp_data_generator = GPDataset(n_data=args["input_dim"], kernel=kernel, sample_lengthscale=True)

# %%
sample_x_train, sample_y_train, sample_ls_train = gp_data_generator.simulatedata(n_samples=1000)
x_test, y_test, ls_test = gp_data_generator.simulatedata(n_samples=1000)

# %%
fig, ax = plt.subplots(figsize=(4,3))
for i in range(15):
    if sample_ls_train[i] <= 0.2:
        col = 'orange'
    elif sample_ls_train[i] <= 0.6:
        col = 'green'
    else:
        col = 'blue'
    ax.plot(sample_x_train[i], sample_y_train[i], color=col)
ax.set_xlabel('$x$')
ax.set_ylabel('$y=f(x)$')
ax.set_title('Example GP trajectories')

plt.show()

# %%
# Plot sample lengthscales
plt.figure(figsize=(4,3))
plt.hist(sample_ls_train[:, 0], alpha = 0.3, label = 'train ls') 
plt.hist(ls_test[:, 0],  alpha = 0.3, label = 'test ls') 
plt.xlim(0,1)
plt.legend()
plt.show()

# %% [markdown]
# ### PriorCVAE Model
#
# We define the PriorCVAE model, optimizer, and initialize the parameters of the model randomly.

# %%
conditional = args["conditional"]
out_dim = args["input_dim"]
hidden_dim = args["hidden_dim"]
activation_fn = args["activation_fn"]
latent_dim = args["latent_dim"]
batch_size = args["batch_size"]
num_iterations  = args["num_iterations"]
true_ls = args["true_ls"]
learning_rate = args["learning_rate"]
vae_var = args["vae_var"]
loss = args["loss"]

# %%
encoder = MLPEncoder(hidden_dim, latent_dim, activation_fn)
decoder = MLPDecoder(hidden_dim, out_dim, activation_fn)
# [ 3501] training loss: 859.449, test loss: 8533.699
# [ 3511] training loss: 800.048, test loss: 8527.264
# [ 3521] training loss: 825.548, test loss: 8585.859
# [ 3531] training loss: 884.571, test loss: 8649.127
# [ 3541] training loss: 801.325, test loss: 8550.962
# [ 3551] training loss: 913.282, test loss: 8574.738
# [ 3561] training loss: 903.149, test loss: 8469.343
# [ 3571] training loss: 772.143, test loss: 8647.885
# [ 3581] training loss: 896.419, test loss: 8517.828
# [ 3591] training loss: 867.128, test loss: 8458.959
# [ 3601] training loss: 855.687, test loss: 8562.124
# [ 3611] training loss: 839.401, test loss: 8659.360
# [ 3621] training loss: 830.994, test loss: 8573.938
# [ 3631] training loss: 873.670, test loss: 8452.102
# [ 3641] training loss: 909.098, test loss: 8498.464
# [ 3651] training loss: 801.851, test loss: 8483.175
# [ 3661] training loss: 916.876, test loss: 8542.312
# [ 3671] training loss: 799.788, test loss: 8538.456
# [ 3681] training loss: 810.291, test loss: 8517.595
# [ 3691] training loss: 848.634, test loss: 8510.441
# [ 3701] training loss: 751.952, test loss: 8492.714
# [ 3711] training loss: 830.743, test loss: 8561.246
# [ 3721] training loss: 854.925, test loss: 8486.487
# [ 3731] training loss: 779.189, test loss: 8565.443
# [ 3741] training loss: 754.401, test loss: 8446.919
# [ 3751] training loss: 938.863, test loss: 8542.563
# [ 3761] training loss: 750.822, test loss: 8579.431
# [ 3771] training loss: 875.458, test loss: 8567.873
# [ 3781] training loss: 751.310, test loss: 8552.898
# [ 3791] training loss: 917.772, test loss: 8465.589
# [ 3801] training loss: 738.985, test loss: 8491.760
# [ 3811] training loss: 879.643, test loss: 8365.454
# [ 3821] training loss: 854.322, test loss: 8480.769
# [ 3831] training loss: 852.896, test loss: 8512.446
# [ 3841] training loss: 804.325, test loss: 8406.572
# [ 3851] training loss: 921.738, test loss: 8526.815
# [ 3861] training loss: 761.236, test loss: 8446.564
# [ 3871] training loss: 892.820, test loss: 8479.399
# [ 3881] training loss: 849.307, test loss: 8524.509
# [ 3891] training loss: 873.424, test loss: 8556.895
# [ 3901] training loss: 1176.359, test loss: 8506.261
# [ 3911] training loss: 717.697, test loss: 8544.656
# [ 3921] training loss: 767.997, test loss: 8551.921
# [ 3931] training loss: 759.264, test loss: 8451.696
# [ 3941] training loss: 976.416, test loss: 8482.428
# [ 3951] training loss: 821.746, test loss: 8429.449
# [ 3961] training loss: 770.638, test loss: 8509.251
# [ 3971] training loss: 851.819, test loss: 8444.463
# [ 3981] training loss: 820.181, test loss: 8449.198
# [ 3991] training loss: 820.494, test loss: 8517.004
# Training of 4000 iterations took 1103 seconds

# %%
fig, axs = plt.subplots(1, 2, figsize=(8, 3))

axs[0].plot(range(len(loss_vals)), loss_vals)
axs[0].set_title('Training loss')

axs[1].plot(range(len(test_vals)), test_vals)
axs[1].set_title("Test loss")
# Out:
# Text(0.5, 1.0, 'Test loss')

# %% [markdown]
# ### Trained Decoder
#
# We plot a sample of trajectories from the trained decoder model.

# %%
decoder_params = trainer.state.params['decoder']
key = jax.random.PRNGKey(rnd.randint(0, 9999))
rng, z_rng, init_rng = random.split(key, 3)
z = random.normal(z_rng, (batch_size, latent_dim))

decoder = MLPDecoder(hidden_dim, out_dim, activation_fn)

c = true_ls * jnp.ones((z.shape[0], 1))
z_c = jnp.concatenate([z, c], axis=-1)
out = decoder.apply({'params': decoder_params}, z_c)             

fig, ax = plt.subplots(figsize=(4,3))
for i in range(15):
    ax.plot(sample_x_train[0], out[i,:])
ax.set_xlabel('$x$')
ax.set_ylabel('$y=f_{VAE}(x)$')
ax.set_title('Examples of learnt trajectories')

plt.show()

# %% [markdown]
# ### Inference with MCMC
#
# We randomly generate observations from the GP.

# %% [markdown]
# #### Generate data

# %%
x = sample_x_train[0]

rng_key_draw =  random.PRNGKey(1)
rng_key, rng_key_post, rng_key_preds, rng_key_draw = random.split(rng_key_draw, 4)

kernel = SquaredExponential(lengthscale=true_ls, variance=1.)
gp_predictive = Predictive(GP, num_samples=1)
draws = gp_predictive(rng_key_draw, kernel=kernel, x=x, jitter=1e-6, noise=True)

gp_draw = draws['f'].T
y_draw = draws['y'].T

# indices of data points
obs_idx = jnp.array([2, 13, 24, 39, 48])
y_obs = y_draw[obs_idx,0]
x_obs = x[np.array(obs_idx)]

plt.figure(figsize=(4,3))
plt.plot(x, gp_draw, label="ground truth", color="orange")
plt.scatter(x_obs, y_obs, color="red", label="observed data", s=60)
plt.title('Ground truth, corresponds to $ls$=' + str(args["true_ls"]))
# Out:
# Text(0.5, 1.0, 'Ground truth, corresponds to $ls$=0.2')

# %% [markdown]
# ### Numpyro model
#
# We define a Nupmyro model to run MCMC.

# %%
# add data to args. This is used by MCMC.
args["y_obs"] = y_obs
args["obs_idx"] = obs_idx

# %%
c = true_ls * jnp.ones((1, )) if conditional else None

mcmc_vae, mcmc_vae_samples, t_elapsed = run_mcmc_vae(rng_key_post, vae_mcmc_inference_model, args, decoder, 
                                                     decoder_params, c=c)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#                 mean       std    median      5.0%     95.0%     n_eff     r_hat
#       f[0]     -0.63      0.17     -0.63     -0.90     -0.36  16150.94      1.00
#       f[1]     -0.64      0.17     -0.64     -0.92     -0.37  16504.72      1.00
#       f[2]     -0.66      0.17     -0.65     -0.95     -0.39  16731.36      1.00
#       f[3]     -0.69      0.17     -0.68     -0.95     -0.40  16687.34      1.00
#       f[4]     -0.72      0.17     -0.71     -0.99     -0.44  16528.50      1.00
#       f[5]     -0.75      0.16     -0.75     -1.01     -0.48  16487.66      1.00
#       f[6]     -0.81      0.16     -0.81     -1.07     -0.55  16348.82      1.00
#       f[7]     -0.86      0.15     -0.86     -1.10     -0.60  16160.76      1.00
#       f[8]     -0.93      0.15     -0.92     -1.17     -0.68  16210.20      1.00
#       f[9]     -0.97      0.14     -0.97     -1.20     -0.73  16255.02      1.00
#      f[10]     -1.04      0.14     -1.04     -1.26     -0.80  16217.66      1.00
#      f[11]     -1.12      0.14     -1.12     -1.34     -0.89  16124.72      1.00
#      f[12]     -1.18      0.14     -1.19     -1.42     -0.97  16232.11      1.00
#      f[13]     -1.24      0.14     -1.24     -1.45     -1.00  16084.15      1.00
#      f[14]     -1.29      0.14     -1.30     -1.52     -1.06  16217.57      1.00
#      f[15]     -1.35      0.15     -1.36     -1.58     -1.11  16149.19      1.00
#      z[17]     -0.27      0.98     -0.28     -1.83      1.38  19582.09      1.00
#      z[18]     -1.13      0.84     -1.14     -2.50      0.24  13824.86      1.00
#      z[19]     -0.01      0.99     -0.01     -1.66      1.58  19107.39      1.00
#      z[20]     -0.06      1.00     -0.06     -1.69      1.59  21499.99      1.00
#      z[21]     -0.00      0.99     -0.01     -1.59      1.66  20204.63      1.00
#      z[22]     -0.01      1.00     -0.00     -1.65      1.64  23080.08      1.00
#      z[23]      0.03      1.00      0.03     -1.60      1.68  19154.45      1.00
#      z[24]     -0.19      0.98     -0.20     -1.83      1.36  20130.62      1.00
#      z[25]     -0.20      0.99     -0.20     -1.88      1.40  19017.64      1.00
#      z[26]      0.01      0.99      0.01     -1.71      1.54  20435.60      1.00
#      z[27]     -0.07      1.00     -0.07     -1.67      1.61  20489.26      1.00
#      z[28]      0.19      0.73      0.19     -0.94      1.47   5889.42      1.00
#      z[29]      0.04      1.01      0.03     -1.59      1.73  19467.43      1.00
#      z[30]      0.06      0.99      0.07     -1.57      1.69  17695.68      1.00
#      z[31]     -0.06      1.00     -0.06     -1.69      1.58  21810.85      1.00
#      z[32]      1.05      0.76      1.08     -0.23      2.26   8035.04      1.00
#      z[33]     -0.10      1.00     -0.11     -1.77      1.54  24224.00      1.00
#      z[34]     -0.01      0.98     -0.01     -1.65      1.59  18866.87      1.00
#      z[35]      0.11      1.01      0.11     -1.54      1.75  18867.46      1.00
#      z[36]      0.05      1.00      0.04     -1.63      1.66  22048.31      1.00
#      z[37]     -0.16      0.99     -0.17     -1.84      1.40  19514.41      1.00
#      z[38]     -0.03      0.99     -0.03     -1.68      1.58  22742.69      1.00
#      z[39]      0.08      1.00      0.08     -1.56      1.70  18111.24      1.00
#
# Number of divergences: 0
#
# MCMC elapsed time: 3 s
# Average ESS for all VAE-GP effects : 13249

# %% [markdown]
# ## Plotting
#
# We plot the trajectory after MCMC.

# %%
predictive = Predictive(vae_mcmc_inference_model, mcmc_vae_samples)

c = true_ls * jnp.ones((1, )) if conditional else None
predictions_vae = predictive(rng_key_preds, args, decoder, decoder_params, c)["f"]

mean_post_pred_vae = jnp.mean(predictions_vae, axis=0)
hpdi_post_pred_vae = hpdi(predictions_vae, 0.9)
percentiles_vae = np.percentile(predictions_vae, [5.0, 95.0], axis=0)

N_lines = 10

plt.figure(figsize=(4,3))
plt.plot(x, gp_draw, label="ground truth", color="orange")
plt.scatter(x_obs, y_obs, color="red", label="observed data", s=60)
plt.title('Ground truth, corresponds to $ls$=' + str(args["true_ls"]))

plt.plot(x, mean_post_pred_vae, label="predicted mean VAE")
plt.fill_between(x, percentiles_vae[0, :], percentiles_vae[1, :], alpha=0.3, interpolate=True, 
                 label="VAE posterior: 90% BCI")

y_min = min(np.concatenate([y_obs, mean_post_pred_vae, percentiles_vae[0, :]]))
y_max = max(np.concatenate([y_obs, mean_post_pred_vae, percentiles_vae[1, :]]))

plt.ylim([y_min, y_max])

plt.title('PriorCVAE inference')
# Out:
# Text(0.5, 1.0, 'PriorCVAE inference')
