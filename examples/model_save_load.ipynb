# %% [markdown]
# ## Saved and load the trained model
#
# This notebook showcases how to save and load a trained model.

# %%
import random as rnd

import numpy as np 
import matplotlib.pyplot as plt
import numpyro
from numpyro.infer import Predictive
from numpyro.diagnostics import hpdi
numpyro.set_host_device_count(4)
import jax
import optax
from jax import random
import jax.numpy as jnp

from priorCVAE.models import MLPEncoder, MLPDecoder, VAE
from priorCVAE.priors import SquaredExponential
from priorCVAE.datasets import GPDataset
from priorCVAE.trainer import VAETrainer
from priorCVAE.losses import SquaredSumAndKL
from priorCVAE.utility import save_model_params, load_model_params

import jax.config as config
config.update("jax_enable_x64", True)

# %%
# Configuration dictionary
args = {
        "input_dim" : 40,
        "hidden_dim": 40,
        "latent_dim": 30,
        "batch_size": 500,
        "num_iterations": 2000,
        "model_path": f"output/{rnd.randint(0, 200)}"
       }

# %% [markdown]
# ### Generate data and train a model
#
# We generate data using a SquaredExponential Kernel with a fixed lengthscale of $0.4$ and train a priorCVAE model.

# %%
kernel = SquaredExponential(lengthscale=.4)

gp_set = GPDataset(n_data=args["input_dim"], kernel=kernel, sample_lengthscale=False)  

sample_x_train, sample_y_train, sample_ls_train = gp_set.simulatedata(n_samples=1000)
x_test, y_test, ls_test = gp_set.simulatedata(n_samples=50)

# %%
encoder = MLPEncoder(args["hidden_dim"], args["latent_dim"])
decoder = MLPDecoder(args["hidden_dim"], args["input_dim"])
model = VAE(encoder, decoder)

optimizer = optax.adam(learning_rate=0.001)
loss = SquaredSumAndKL(conditional=True)

trainer = VAETrainer(model, optimizer, loss=loss)
trainer.init_params(sample_y_train[0], c=sample_ls_train[0])

test_set = (x_test, y_test, ls_test)
loss_vals, test_vals, time_taken = trainer.train(gp_set, test_set, args["num_iterations"])

print(f'Training of {args["num_iterations"]} epochs took {round(time_taken)} seconds')
# Out:
# [    1] training loss: 3085.191, test loss: 1338.058
# [   11] training loss: 2532.998, test loss: 1053.147
# [   21] training loss: 2371.922, test loss: 898.639
# [   31] training loss: 2245.007, test loss: 834.654
# [   41] training loss: 2062.021, test loss: 789.798
# [   51] training loss: 2269.719, test loss: 754.239
# [   61] training loss: 1741.419, test loss: 714.536
# [   71] training loss: 1991.236, test loss: 711.524
# [   81] training loss: 1632.883, test loss: 641.615
# [   91] training loss: 1780.438, test loss: 611.640
# [  101] training loss: 1681.694, test loss: 588.433
# [  111] training loss: 1278.830, test loss: 505.245
# [  121] training loss: 1375.943, test loss: 505.835
# [  131] training loss: 1262.463, test loss: 520.566
# [  141] training loss: 1207.508, test loss: 472.672
# [  151] training loss: 1213.763, test loss: 441.730
# [  161] training loss: 1301.338, test loss: 450.122
# [  171] training loss: 953.379, test loss: 435.285
# [  181] training loss: 947.776, test loss: 413.811
# [  191] training loss: 963.722, test loss: 399.435
# [  201] training loss: 882.492, test loss: 416.671
# [  211] training loss: 942.061, test loss: 457.168
# [  221] training loss: 953.691, test loss: 389.504
# [  231] training loss: 856.160, test loss: 380.952
# [  241] training loss: 844.392, test loss: 395.991
# [  251] training loss: 896.756, test loss: 394.215
# [  261] training loss: 984.535, test loss: 353.917
# [  271] training loss: 857.580, test loss: 364.241
# [  281] training loss: 864.331, test loss: 400.494
# [  291] training loss: 899.397, test loss: 409.624
# [  301] training loss: 950.939, test loss: 352.654
# [  311] training loss: 871.417, test loss: 339.507
# [  321] training loss: 884.622, test loss: 453.464
# [  331] training loss: 850.891, test loss: 344.394
# [  341] training loss: 811.311, test loss: 360.949
# [  351] training loss: 916.758, test loss: 373.417
# [  361] training loss: 831.855, test loss: 334.854
# [  371] training loss: 860.006, test loss: 380.470
# [  381] training loss: 853.799, test loss: 311.780
# [  391] training loss: 855.989, test loss: 339.576
# [  401] training loss: 748.252, test loss: 321.398
# [  411] training loss: 919.452, test loss: 362.690
# [  421] training loss: 774.840, test loss: 369.144
# [  431] training loss: 770.905, test loss: 364.882
# [  441] training loss: 750.467, test loss: 297.683
# [  451] training loss: 739.157, test loss: 340.323
# [  461] training loss: 798.331, test loss: 353.310
# [  471] training loss: 837.169, test loss: 314.593
# [  481] training loss: 800.584, test loss: 354.144
# [  491] training loss: 707.906, test loss: 318.570
# [  501] training loss: 773.045, test loss: 331.457
# [  511] training loss: 821.464, test loss: 349.631
# [  521] training loss: 729.557, test loss: 328.783
# [  531] training loss: 697.923, test loss: 338.396
# [  541] training loss: 661.710, test loss: 291.259
# [  551] training loss: 815.516, test loss: 324.517
# [  561] training loss: 844.758, test loss: 321.167
# [  571] training loss: 738.328, test loss: 336.020
# [  581] training loss: 684.229, test loss: 297.408
# [  591] training loss: 726.762, test loss: 272.710
# [  601] training loss: 709.177, test loss: 300.415
# [  611] training loss: 697.959, test loss: 297.944
# [  621] training loss: 725.211, test loss: 256.441
# [  631] training loss: 751.263, test loss: 287.250
# [  641] training loss: 742.004, test loss: 279.580
# [  651] training loss: 628.980, test loss: 280.625
# [  661] training loss: 690.600, test loss: 280.314
# [  671] training loss: 680.735, test loss: 276.500
# [  681] training loss: 660.991, test loss: 269.134
# [  691] training loss: 720.077, test loss: 299.096
# [  701] training loss: 709.747, test loss: 264.349
# [  711] training loss: 604.371, test loss: 293.400
# [  721] training loss: 638.407, test loss: 266.824
# [  731] training loss: 587.568, test loss: 266.427
# [  741] training loss: 614.693, test loss: 279.586
# [  751] training loss: 622.706, test loss: 268.621
# [  761] training loss: 589.449, test loss: 248.861
# [  771] training loss: 588.052, test loss: 263.138
# [  781] training loss: 628.587, test loss: 257.967
# [  791] training loss: 659.546, test loss: 234.794
# [  801] training loss: 630.891, test loss: 270.224
# [  811] training loss: 611.930, test loss: 299.850
# [  821] training loss: 561.760, test loss: 256.252
# [  831] training loss: 582.895, test loss: 252.207
# [  841] training loss: 625.911, test loss: 268.956
# [  851] training loss: 573.339, test loss: 261.089
# [  861] training loss: 598.719, test loss: 273.498
# [  871] training loss: 615.641, test loss: 254.630
# [  881] training loss: 565.346, test loss: 258.348
# [  891] training loss: 622.773, test loss: 266.490
# [  901] training loss: 586.731, test loss: 248.693
# [  911] training loss: 599.460, test loss: 248.454
# [  921] training loss: 560.538, test loss: 230.866
# [  931] training loss: 556.994, test loss: 246.680
# [  941] training loss: 581.980, test loss: 250.906
# [  951] training loss: 508.490, test loss: 245.813
# [  961] training loss: 585.097, test loss: 260.936
# [  971] training loss: 558.093, test loss: 235.874
# [  981] training loss: 495.923, test loss: 262.408
# [  991] training loss: 524.681, test loss: 247.398
# [ 1001] training loss: 555.124, test loss: 266.893
# [ 1011] training loss: 561.609, test loss: 256.888
# [ 1021] training loss: 562.567, test loss: 251.556
# [ 1031] training loss: 508.860, test loss: 258.796
# [ 1041] training loss: 565.747, test loss: 249.285
# [ 1051] training loss: 508.056, test loss: 246.455
# [ 1061] training loss: 531.031, test loss: 247.094
# [ 1071] training loss: 517.880, test loss: 251.215
# [ 1081] training loss: 507.213, test loss: 250.053
# [ 1091] training loss: 538.114, test loss: 233.306
# [ 1101] training loss: 529.033, test loss: 255.709
# [ 1111] training loss: 570.289, test loss: 256.206
# [ 1121] training loss: 505.907, test loss: 232.838
# [ 1131] training loss: 569.549, test loss: 233.240
# [ 1141] training loss: 536.386, test loss: 231.712
# [ 1151] training loss: 541.203, test loss: 239.722
# [ 1161] training loss: 507.042, test loss: 233.090
# [ 1171] training loss: 504.293, test loss: 224.385
# [ 1181] training loss: 538.254, test loss: 232.477
# [ 1191] training loss: 529.135, test loss: 242.014
# [ 1201] training loss: 537.791, test loss: 241.245
# [ 1211] training loss: 528.038, test loss: 232.489
# [ 1221] training loss: 535.362, test loss: 237.163
# [ 1231] training loss: 475.885, test loss: 246.594
# [ 1241] training loss: 536.057, test loss: 236.743
# [ 1251] training loss: 495.275, test loss: 231.669
# [ 1261] training loss: 483.202, test loss: 236.430
# [ 1271] training loss: 559.053, test loss: 232.758
# [ 1281] training loss: 530.781, test loss: 230.068
# [ 1291] training loss: 544.077, test loss: 229.962
# [ 1301] training loss: 503.684, test loss: 233.964
# [ 1311] training loss: 506.578, test loss: 231.065
# [ 1321] training loss: 514.203, test loss: 244.717
# [ 1331] training loss: 576.732, test loss: 248.654
# [ 1341] training loss: 477.986, test loss: 240.484
# [ 1351] training loss: 505.333, test loss: 231.454
# [ 1361] training loss: 532.758, test loss: 232.401
# [ 1371] training loss: 523.311, test loss: 245.910
# [ 1381] training loss: 495.994, test loss: 233.491
# [ 1391] training loss: 496.358, test loss: 232.305
# [ 1401] training loss: 518.008, test loss: 237.232
# [ 1411] training loss: 505.780, test loss: 239.445
# [ 1421] training loss: 511.835, test loss: 224.044
# [ 1431] training loss: 517.636, test loss: 237.026
# [ 1441] training loss: 515.619, test loss: 240.495
# [ 1451] training loss: 543.430, test loss: 237.329
# [ 1461] training loss: 470.270, test loss: 241.473
# [ 1471] training loss: 478.953, test loss: 235.941
# [ 1481] training loss: 520.160, test loss: 244.864
# [ 1491] training loss: 453.551, test loss: 228.738
# [ 1501] training loss: 550.262, test loss: 239.306
# [ 1511] training loss: 509.937, test loss: 233.846
# [ 1521] training loss: 518.808, test loss: 226.712
# [ 1531] training loss: 543.607, test loss: 231.266
# [ 1541] training loss: 533.206, test loss: 251.971
# [ 1551] training loss: 511.287, test loss: 221.277
# [ 1561] training loss: 525.091, test loss: 238.927
# [ 1571] training loss: 503.536, test loss: 259.756
# [ 1581] training loss: 485.942, test loss: 219.732
# [ 1591] training loss: 492.498, test loss: 228.710
# [ 1601] training loss: 515.815, test loss: 244.748
# [ 1611] training loss: 495.952, test loss: 227.714
# [ 1621] training loss: 548.868, test loss: 240.364
# [ 1631] training loss: 498.956, test loss: 231.469
# [ 1641] training loss: 506.134, test loss: 231.672
# [ 1651] training loss: 512.233, test loss: 233.577
# [ 1661] training loss: 555.419, test loss: 225.104
# [ 1671] training loss: 528.636, test loss: 233.688
# [ 1681] training loss: 465.865, test loss: 241.276
# [ 1691] training loss: 509.699, test loss: 228.184
# [ 1701] training loss: 516.978, test loss: 234.906
# [ 1711] training loss: 557.984, test loss: 223.791
# [ 1721] training loss: 539.644, test loss: 227.684
# [ 1731] training loss: 529.687, test loss: 231.881
# [ 1741] training loss: 510.309, test loss: 242.047
# [ 1751] training loss: 497.005, test loss: 231.843
# [ 1761] training loss: 513.625, test loss: 234.041
# [ 1771] training loss: 522.891, test loss: 235.912
# [ 1781] training loss: 497.327, test loss: 224.931
# [ 1791] training loss: 498.698, test loss: 247.570
# [ 1801] training loss: 509.057, test loss: 245.685
# [ 1811] training loss: 498.779, test loss: 248.148
# [ 1821] training loss: 520.621, test loss: 247.285
# [ 1831] training loss: 539.066, test loss: 239.604
# [ 1841] training loss: 537.552, test loss: 222.129
# [ 1851] training loss: 502.296, test loss: 222.234
# [ 1861] training loss: 492.308, test loss: 243.473
# [ 1871] training loss: 508.534, test loss: 234.701
# [ 1881] training loss: 507.681, test loss: 239.253
# [ 1891] training loss: 468.984, test loss: 229.171
# [ 1901] training loss: 506.152, test loss: 228.991
# [ 1911] training loss: 496.906, test loss: 224.225
# [ 1921] training loss: 541.150, test loss: 237.786
# [ 1931] training loss: 480.756, test loss: 243.731
# [ 1941] training loss: 519.632, test loss: 226.327
# [ 1951] training loss: 529.892, test loss: 229.899
# [ 1961] training loss: 509.055, test loss: 248.044
# [ 1971] training loss: 504.383, test loss: 224.063
# [ 1981] training loss: 537.873, test loss: 221.831
# [ 1991] training loss: 495.347, test loss: 239.430
# Training of 2000 epochs took 270 seconds

# %% [markdown]
# ## Save the model
#
# Save the parameters of a trained model.

# %%
save_model_params(args["model_path"], trainer.state.params)

# %% [markdown]
# ## Create a new decoder
#
# We create a new decoder, initialize the parameters randomly and plot a few sampples.

# %%
new_decoder = MLPDecoder(args["hidden_dim"], args["input_dim"])

key = jax.random.PRNGKey(rnd.randint(0, 9999))
rng, z_rng, init_rng = random.split(key, 3)
z = random.normal(z_rng, (args["batch_size"], args["latent_dim"]))
c = .4 * jnp.ones((z.shape[0], 1))
z_c = jnp.concatenate([z, c], axis=-1)

key = jax.random.PRNGKey(rnd.randint(0, 9999))
key, rng = jax.random.split(key, 2)
params = new_decoder.init(rng, z_c)['params']

out = new_decoder.apply({'params': params}, z_c)             

fig, ax = plt.subplots(figsize=(4,3))
for i in range(15):
    ax.plot(sample_x_train[0], out[i,:])
ax.set_xlabel('$x$')
ax.set_ylabel('$y=f_{VAE}(x)$')
ax.set_title('Examples of decoder output')

plt.show()

# %% [markdown]
# ## Load the model
#
# Now, we load the trained parameters from the saved model file and plots the samples from the decoder again.

# %%
trained_decoder_params = load_model_params(args["model_path"])["decoder"]

# %%
# apply decoder with trained parameters on the data
out = new_decoder.apply({'params': trained_decoder_params}, z_c)             

fig, ax = plt.subplots(figsize=(4,3))
for i in range(15):
    ax.plot(sample_x_train[0], out[i,:])
ax.set_xlabel('$x$')
ax.set_ylabel('$y=f_{VAE}(x)$')
ax.set_title('Examples of decoder output')

plt.show()
